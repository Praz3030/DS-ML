# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
df=pd.read_csv("C:\\Users\\nikhi\\Desktop\\New folder\\ab.csv")

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
df.STATUS.value_counts().plot()
# Out:
# <Axes: xlabel='STATUS'>

# %%
df.STATUS.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='STATUS'>

# %% [markdown]
# ![](Katta_login_bg_3.jpg)

# %% [markdown]
# # **Prasad**

# %% [markdown]
# ls

# %% [markdown]
# ls

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B424-2B37
#
#  Directory of C:\Users\nikhi\Prasad\sample_project
#
# 27-02-2024  11.48 AM    <DIR>          .
# 27-02-2024  09.26 AM    <DIR>          ..
# 27-02-2024  10.47 AM    <DIR>          .ipynb_checkpoints
# 27-02-2024  11.30 AM         3,461,400 ab.csv
# 27-02-2024  11.06 AM    <DIR>          env
# 27-02-2024  11.48 AM            49,792 first.ipynb
# 27-02-2024  11.42 AM            52,858 Katta_login_bg_3.jpg
# 27-02-2024  10.47 AM                72 Untitled.ipynb
#                4 File(s)      3,564,122 bytes
#                4 Dir(s)  107,887,521,792 bytes free

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B424-2B37
#
#  Directory of C:\Users\nikhi\Prasad\sample_project
#
# 27-02-2024  11.48 AM    <DIR>          .
# 27-02-2024  09.26 AM    <DIR>          ..
# 27-02-2024  10.47 AM    <DIR>          .ipynb_checkpoints
# 27-02-2024  11.30 AM         3,461,400 ab.csv
# 27-02-2024  11.06 AM    <DIR>          env
# 27-02-2024  11.48 AM            49,792 first.ipynb
# 27-02-2024  11.42 AM            52,858 Katta_login_bg_3.jpg
# 27-02-2024  10.47 AM                72 Untitled.ipynb
#                4 File(s)      3,564,122 bytes
#                4 Dir(s)  107,887,505,408 bytes free

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B424-2B37
#
#  Directory of C:\Users\nikhi\Prasad\sample_project
#
# 27-02-2024  11.50 AM    <DIR>          .
# 27-02-2024  09.26 AM    <DIR>          ..
# 27-02-2024  10.47 AM    <DIR>          .ipynb_checkpoints
# 27-02-2024  11.30 AM         3,461,400 ab.csv
# 27-02-2024  11.06 AM    <DIR>          env
# 27-02-2024  11.50 AM            52,448 first.ipynb
# 27-02-2024  11.42 AM            52,858 Katta_login_bg_3.jpg
# 27-02-2024  10.47 AM                72 Untitled.ipynb
#                4 File(s)      3,566,778 bytes
#                4 Dir(s)  107,882,373,120 bytes free

# %%
a=9

# %%
a
# Out:
# 9

# %%
import pandas as pd

# %%
cars=pd.Series(["BMW","TVS","TATA"])
cars
# Out:
# 0     BMW
# 1     TVS
# 2    TATA
# dtype: object

# %%
colors=pd.Series(["Red","Yellow","Green","White"])

# %%
colors
# Out:
# 0       Red
# 1    Yellow
# 2     Green
# 3     White
# dtype: object

# %%
Cars_data=pd.DataFrame({"Cars":cars,"Colors":colors})

# %%
Cars_data
# Out:
#    Cars  Colors
# 0   BMW     Red
# 1   TVS  Yellow
# 2  TATA   Green
# 3   NaN   White

# %%
import pandas as pd

# %%
xls=pd.read_excel("file_example_XLS_10.xlsx")

# %%
xls.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
abc=pd.DataFrame({"F_name":xls[xls["Age"]>30]["Country"],"Age":xls[xls["Age"]>30]["Age"]})
abc
# Out:
#           F_name  Age
# 0  United States   32
# 2         France   36
# 4  United States   58
# 6  Great Britain   56
# 8  United States   40

# %%
import pandas as pd

# %%
xls=pd.read_excel("file_example_XLS_10.xlsx")

# %%
abc=pd.DataFrame({"F_name":xls[xls["Age"]>30]["Country"],"Age":xls[xls["Age"]>30]["Age"]})
abc
# Out:
#           F_name  Age
# 0  United States   32
# 2         France   36
# 4  United States   58
# 6  Great Britain   56
# 8  United States   40

# %%
abc.to_csv("New_Country_Data.csv",index=False)

# %%
ncd=pd.read_csv("New_Country_Data.csv")

# %%
ncd
# Out:
#           F_name  Age
# 0  United States   32
# 1         France   36
# 2  United States   58
# 3  Great Britain   56
# 4  United States   40

# %% [markdown]
# ### Describe Data

# %%
ncd=pd.read_csv("New_Country_Data.csv")

# %%
xls
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
xls[(xls["Age"]>30)&(xls["Id"]>2000)]
# Out:
#    0 First Name Last Name  Gender        Country  Age        Date    Id
# 2  3     Philip      Gent    Male         France   36  21/05/2015  2587
# 4  5    Nereida   Magwood  Female  United States   58  16/08/2016  2468
# 6  7       Etta      Hurn  Female  Great Britain   56  15/10/2017  3598
# 8  9   Vincenza   Weiland  Female  United States   40  21/05/2015  6548

# %%
xls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 xls
#
# NameError: name 'xls' is not defined

# %%
import pandas as pd

# %%
xls
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
xls["First Name"][2]="nik"
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_2672\2595378402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xls["First Name"][2]="nik"

# %%
xls
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1     Prasad      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3        nik       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
xls.loc[5,"First Name"]="Pooja"

# %%
xls
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1     Prasad      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3        nik       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6      Pooja      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
n=xls["Country"].size

# %%
n
# Out:
# 9

# %%
for i in range(0,n):
    xls.loc[i,"Country"]="India"

# %%
xls
# Out:
#    0 First Name  Last Name  Gender Country  Age        Date    Id
# 0  1     Prasad      Abril  Female   India   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female   India   25  16/08/2016  1582
# 2  3        nik       Gent    Male   India   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female   India   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female   India   58  16/08/2016  2468
# 5  6      Pooja      Brumm    Male   India   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female   India   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female   India   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female   India   40  21/05/2015  6548

# %%
xls["Age"].mean()
# Out:
# 35.888888888888886

# %%
xls["Age"].std()
# Out:
# 13.147665614515418

# %%
display(xls)
# Out:
#    0 First Name  Last Name  Gender Country  Age        Date    Id
# 0  1     Prasad      Abril  Female   India   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female   India   25  16/08/2016  1582
# 2  3        nik       Gent    Male   India   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female   India   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female   India   58  16/08/2016  2468
# 5  6      Pooja      Brumm    Male   India   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female   India   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female   India   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female   India   40  21/05/2015  6548

# %%
xls.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
len(xls.index)
# Out:
# 9

# %%
import numpy as np

# %%
xls.loc[10]=np.nan

# %%
xls.dropna()
# Out:
#      0 First Name  Last Name  Gender Country   Age        Date      Id
# 0  1.0     Prasad      Abril  Female   India  32.0  15/10/2017  1562.0
# 1  2.0       Mara  Hashimoto  Female   India  25.0  16/08/2016  1582.0
# 2  3.0        nik       Gent    Male   India  36.0  21/05/2015  2587.0
# 3  4.0   Kathleen     Hanner  Female   India  25.0  15/10/2017  3549.0
# 4  5.0    Nereida    Magwood  Female   India  58.0  16/08/2016  2468.0
# 5  6.0      Pooja      Brumm    Male   India  24.0  21/05/2015  2554.0
# 6  7.0       Etta       Hurn  Female   India  56.0  15/10/2017  3598.0
# 7  8.0    Earlean     Melgar  Female   India  27.0  16/08/2016  2456.0
# 8  9.0   Vincenza    Weiland  Female   India  40.0  21/05/2015  6548.0
# 9  9.0     Andrew       Tate    Male   India  50.0  15/10/2034  2321.0

# %%
xls.dropna(inplace=True)

# %%
xls
# Out:
#      0 First Name  Last Name  Gender Country   Age        Date      Id
# 0  1.0     Prasad      Abril  Female   India  32.0  15/10/2017  1562.0
# 1  2.0       Mara  Hashimoto  Female   India  25.0  16/08/2016  1582.0
# 2  3.0        nik       Gent    Male   India  36.0  21/05/2015  2587.0
# 3  4.0   Kathleen     Hanner  Female   India  25.0  15/10/2017  3549.0
# 4  5.0    Nereida    Magwood  Female   India  58.0  16/08/2016  2468.0
# 5  6.0      Pooja      Brumm    Male   India  24.0  21/05/2015  2554.0
# 6  7.0       Etta       Hurn  Female   India  56.0  15/10/2017  3598.0
# 7  8.0    Earlean     Melgar  Female   India  27.0  16/08/2016  2456.0
# 8  9.0   Vincenza    Weiland  Female   India  40.0  21/05/2015  6548.0
# 9  9.0     Andrew       Tate    Male   India  50.0  15/10/2034  2321.0

# %%
xls["add"]=pd.Series([1,2])

# %%
xls
# Out:
#      0 First Name  Last Name  Gender Country   Age        Date      Id  add
# 0  1.0     Prasad      Abril  Female   India  32.0  15/10/2017  1562.0  1.0
# 1  2.0       Mara  Hashimoto  Female   India  25.0  16/08/2016  1582.0  2.0
# 2  3.0        nik       Gent    Male   India  36.0  21/05/2015  2587.0  NaN
# 3  4.0   Kathleen     Hanner  Female   India  25.0  15/10/2017  3549.0  NaN
# 4  5.0    Nereida    Magwood  Female   India  58.0  16/08/2016  2468.0  NaN
# 5  6.0      Pooja      Brumm    Male   India  24.0  21/05/2015  2554.0  NaN
# 6  7.0       Etta       Hurn  Female   India  56.0  15/10/2017  3598.0  NaN
# 7  8.0    Earlean     Melgar  Female   India  27.0  16/08/2016  2456.0  NaN
# 8  9.0   Vincenza    Weiland  Female   India  40.0  21/05/2015  6548.0  NaN
# 9  9.0     Andrew       Tate    Male   India  50.0  15/10/2034  2321.0  NaN

# %%
xls.fillna(0)
# Out:
#      0 First Name  Last Name  Gender Country   Age        Date      Id  add
# 0  1.0     Prasad      Abril  Female   India  32.0  15/10/2017  1562.0  1.0
# 1  2.0       Mara  Hashimoto  Female   India  25.0  16/08/2016  1582.0  2.0
# 2  3.0        nik       Gent    Male   India  36.0  21/05/2015  2587.0  0.0
# 3  4.0   Kathleen     Hanner  Female   India  25.0  15/10/2017  3549.0  0.0
# 4  5.0    Nereida    Magwood  Female   India  58.0  16/08/2016  2468.0  0.0
# 5  6.0      Pooja      Brumm    Male   India  24.0  21/05/2015  2554.0  0.0
# 6  7.0       Etta       Hurn  Female   India  56.0  15/10/2017  3598.0  0.0
# 7  8.0    Earlean     Melgar  Female   India  27.0  16/08/2016  2456.0  0.0
# 8  9.0   Vincenza    Weiland  Female   India  40.0  21/05/2015  6548.0  0.0
# 9  9.0     Andrew       Tate    Male   India  50.0  15/10/2034  2321.0  0.0

# %%
xls["Full Name"]=xls["First Name"] + " " + xls["Last Name"] + "-" +str(xls["Id"])

# %%
xls
# Out:
#      0 First Name  Last Name  Gender Country   Age        Date      Id  add  \
# 0  1.0     Prasad      Abril  Female   India  32.0  15/10/2017  1562.0  1.0
# 1  2.0       Mara  Hashimoto  Female   India  25.0  16/08/2016  1582.0  2.0
# 2  3.0        nik       Gent    Male   India  36.0  21/05/2015  2587.0  NaN
# 3  4.0   Kathleen     Hanner  Female   India  25.0  15/10/2017  3549.0  NaN
# 4  5.0    Nereida    Magwood  Female   India  58.0  16/08/2016  2468.0  NaN
# 5  6.0      Pooja      Brumm    Male   India  24.0  21/05/2015  2554.0  NaN
# 6  7.0       Etta       Hurn  Female   India  56.0  15/10/2017  3598.0  NaN
# 7  8.0    Earlean     Melgar  Female   India  27.0  16/08/2016  2456.0  NaN
# 8  9.0   Vincenza    Weiland  Female   India  40.0  21/05/2015  6548.0  NaN
# 9  9.0     Andrew       Tate    Male   India  50.0  15/10/2034  2321.0  NaN
#
#                                            Full Name
# 0  Prasad Abril-0    1562.0\n1    1582.0\n2    25...
# ...

# %%
xls=pd.read_excel("file_example_XLS_10.xlsx")

# %%
xls
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
xls=xls.sample(frac=1)

# %%
xls
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562

# %%
xls=xls.reset_index(drop=True,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 xls=xls.reset_index(drop=True,inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
xls

# %%
xls

# %%
xls=pd.read_excel("file_example_XLS_10.xlsx")

# %%
xls
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
xls["Id"]=xls["Id"].apply(lambda x:x-1000)

# %%
xls
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017   562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016   582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  1587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  2549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  1468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  1554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  2598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  1456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  5548
